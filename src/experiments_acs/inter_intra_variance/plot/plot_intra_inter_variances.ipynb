# %% [markdown]
# ## Plot Within-Group and Between-Group Variances

# %%
from experiments_acs.inter_intra_variance.plot.plot_helper import main
from utility.plot_style import set_plot_style

# %%
set_plot_style(sans_serif=False)

# %% [markdown]
# #### Parameters

# %%
experiment_name = "inter_intra_variance"
datetime = "2026-06-26__16-31-50"
cluster = True

# %%
main(experiment_name=experiment_name, datetime=datetime, cluster=cluster)
# Out:
# Found 5 level files with distribution results: ['level_0.json', 'level_1.json', 'level_2.json', 'level_3.json', 'level_4.json']
# {'id': 0, 'parent_id': None, 'level': 'level_0', 'filters': [], 'attributes': [], 'decisive_attribute': 'none', 'decisive_value': 'none', 'target_mean': 44314.587999440824, 'target_var': 5357990582.069097, 'weight_after_filtering': 342612035.0, 'weighted_prior': 1.0}
#
# Results saved to /Users/patrikwolf/code/incontext_learning/results_cluster/inter_intra_variance/2026-06-26__16-31-50/final_summary_results.json
