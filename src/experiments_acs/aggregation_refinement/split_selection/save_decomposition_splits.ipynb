# %% [markdown]
# ## Save Some Good Splits for Analysis

# %%
from experiments_acs.aggregation_refinement.split_selection.split_helper import save_decomposition_dict, \
    load_decomposition_dict

# %% [markdown]
# ### Load Individual Attribute Splits

# %%
attribute_splits = load_decomposition_dict(split_name="attribute_splits")

# %% [markdown]
# #### ESR; ...

# %%
# Define splits
attribute_list = ["MAR", "COW", "OCCP", "ESR"]

decomposition_attributes = {}
for idx, attribute in enumerate(attribute_list):
    decomposition_attributes[f"level_{idx + 1}"] = attribute_splits[attribute]

# Save decomposition dict
save_decomposition_dict(decomposition_attributes=decomposition_attributes, split_name="_".join(attribute_list))

# %% [markdown]
# #### Another split...
