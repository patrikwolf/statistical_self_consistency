# %% [markdown]
# ## Plot Error Gains

# %%
import matplotlib.pyplot as plt

from utility.plot_style import set_plot_style
from experiments_acs.micro_macro_multi.plot_implicit.plot_error_gain import main_error_gain
from experiments_acs.micro_macro_multi.plot_implicit.plot_error import main_abs_error

# %%
# Set style
set_plot_style(sans_serif=False, factor=1.225)

# Line width
plt.rcParams.update({
    "axes.linewidth": 2,
    "grid.linewidth": 1.75,
})

# %%
# Experiment
plot_dir_name = "micro_macro_implicit"

# Load micro to macro results
# todo: change
mtm_experiment_name = "micro_macro_implicit"
mtm_cluster = True
#mtm_timestamp = "2026-06-01__08-30-38"      # GPT-5.4
#mtm_timestamp = "2026-06-02__15-59-14"      # GPT-4o mini
#mtm_timestamp = "2026-06-02__16-39-30"      # Opus 4.7
#mtm_timestamp = "2026-06-02__17-06-01"      # Gemini 3.1 Pro (low reasoning)
mtm_timestamp = "2026-06-03__11-41-12"      # GPT-5.4, minimal changes to prompt template

# Baseline
baseline_experiment_name = "micro_macro_aggregation_baseline"
load_joint_llm_priors = True
#baseline_experiment_log_file = "exp_baseline_gpt54.yaml"            # GPT-5.4
#baseline_experiment_log_file = "exp_baseline_gpt4o_mini.yaml"       # GPT-4o mini
#baseline_experiment_log_file = "exp_baseline_opus.yaml"             # Opus 4.7
#baseline_experiment_log_file = "exp_baseline_gemini_pro.yaml"       # Gemini 3.1 Pro (low reasoning)
baseline_experiment_log_file = "exp_baseline_gpt54.yaml"            # GPT-5.4, minimal changes to prompt template

# Income thresholds
income_thresholds = [100, 20_000, 40_000, 60_000, 80_000]
# income_thresholds = [100, 1_000, 10_000, 20_000, 40_000, 50_000, 60_000, 80_000]

# %% [markdown]
# #### Plot Error Gains

# %%
# Plot results
main_error_gain(
    mtm_experiment_name=mtm_experiment_name,
    mtm_timestamp=mtm_timestamp,
    mtm_cluster=mtm_cluster,
    baseline_experiment_log_file=baseline_experiment_log_file,
    baseline_experiment_name=baseline_experiment_name,
    load_joint_llm_priors=load_joint_llm_priors,
    plot_dir_name=plot_dir_name,
    income_thresholds=income_thresholds,
)
# Out:
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Preparing results for income Threshold: 100
# Preparing results for income Threshold: 20000
# Preparing results for income Threshold: 40000
# Preparing results for income Threshold: 60000
# Preparing results for income Threshold: 80000

# %% [markdown]
# #### Plot Absolute Error

# %%
# Plot results
main_abs_error(
    mtm_experiment_name=mtm_experiment_name,
    mtm_timestamp=mtm_timestamp,
    mtm_cluster=mtm_cluster,
    baseline_experiment_log_file=baseline_experiment_log_file,
    baseline_experiment_name=baseline_experiment_name,
    load_joint_llm_priors=load_joint_llm_priors,
    plot_dir_name=plot_dir_name,
    income_thresholds=income_thresholds,
)
# Out:
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
