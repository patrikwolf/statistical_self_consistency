# %% [markdown]
# ## Plot Aggregated Error

# %%
from experiments_acs.micro_macro_multi.plot_aggregated.plot_aggregated_error import main_processing, plot_avg_error_gains, plot_win_rates

# %% [markdown]
# #### Parameters

# %%
# Specify experiments
models = {
    "gpt54": {
        "model": "openai/gpt-5.4",
        "baseline_yaml": "exp_baseline_gpt54"
    },
    "gpt4o_mini": {
        "model": "openai/gpt-4o-mini",
        "baseline_yaml": "exp_baseline_gpt4o_mini"
    },
    "opus": {
        "model": "anthropic/claude-opus-4.7",
        "baseline_yaml": "exp_baseline_opus"
    },
    "sonnet": {
        "model": "anthropic/claude-sonnet-4.6",
        "baseline_yaml": "exp_baseline_sonnet"
    },
    "gemini_pro": {
        "model": "google/gemini-3.1-pro-preview",
        "baseline_yaml": "exp_baseline_gemini_pro"
    },
    "grok": {
        "model": "x-ai/grok-4.20",
        "baseline_yaml": "exp_baseline_grok"
    }
}

# %% [markdown]
# #### Processing

# %%
# Run main script
detailed_results, plot_results, win_rate_results = main_processing(
    models=models,
    selected_models_win_rate=None,
    selected_threshold_win_rate=None,
)
# Out:
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
#
# Model: openai/gpt-5.4
# Income threshold: 100
# Income threshold: 20000
# Income threshold: 40000
# Income threshold: 60000
# Income threshold: 80000
#
# Model: openai/gpt-4o-mini
# Income threshold: 100
# Income threshold: 20000
# Income threshold: 40000
# Income threshold: 60000
# Income threshold: 80000
#
# Model: anthropic/claude-opus-4.7
# Income threshold: 100
# Income threshold: 20000
# Income threshold: 40000
# Income threshold: 60000
# Income threshold: 80000
#
# Model: anthropic/claude-sonnet-4.6
# Income threshold: 100
# Income threshold: 20000
# Income threshold: 40000
# Income threshold: 60000
# Income threshold: 80000
#
# Model: google/gemini-3.1-pro-preview
# Income threshold: 100
# Income threshold: 20000
# Income threshold: 40000
# Income threshold: 60000
# Income threshold: 80000
#
# Model: x-ai/grok-4.20
# Income threshold: 100
# Income threshold: 20000
# Income threshold: 40000
# Income threshold: 60000
# Income threshold: 80000

# %% [markdown]
# #### Plot 1: Average Error Gain

# %%
# Plot 1: Averaged error gain
plot_avg_error_gains(plot_results=plot_results)

# %% [markdown]
# #### Plot 2: Win Rates

# %%
plot_win_rates(win_rate_results=win_rate_results)
